# %%
# Import required libraries

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %%
# Import and read data
X = pd.read_csv('/home/oktavianu/my-Ai/ML-intermediate/train.csv', index_col='Id')
X_test = pd.read_csv('/home/oktavianu/my-Ai/ML-intermediate/test.csv', index_col='Id')

# %%
# Remove row with missing target
X.dropna(axis=0, subset=['SalePrice'], inplace=True)

# Reparate target from predictors
y = X.SalePrice 
X.drop(['SalePrice'], axis=1, inplace=True)

# %%
# To keep things simple, we'll drop columns with missing values
cols_with_mv = [col for col in X_train.columns if X_train[col].isnull().any()]
X.drop(cols_with_mv, axis=1, inplace=True)
X_test.drop(cols_with_mv, axis=1, inplace=True)

# %%
# Break off Validation set from training data
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=0)

# %%
# view the first five rows
X_train.head()
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 619          20       RL         90.0    11694   Pave   NaN      Reg
# 871          20       RL         60.0     6600   Pave   NaN      Reg
# 93           30       RL         80.0    13360   Pave  Grvl      IR1
# 818          20       RL          NaN    13265   Pave   NaN      IR1
# 303          20       RL        118.0    13704   Pave   NaN      IR1
#
#     LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC Fence  \
# Id                                   ...
# 619         Lvl    AllPub    Inside  ...         260        0    NaN   NaN
# 871         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 93          HLS    AllPub    Inside  ...           0        0    NaN   NaN
# 818         Lvl    AllPub   CulDSac  ...           0        0    NaN   NaN
# 303         Lvl    AllPub    Corner  ...           0        0    NaN   NaN
#
# ...

# %%
# Function to compare different approaches
def score_dataset(X_train, X_valid, y_train, y_valid):
    model = RandomForestRegressor(n_estimator=100, random_state=0) # Initialize model
    model.fit(X_train, y_train) # Train model
    preds = model.predict(X_valid)
    return mean_absolute_error(preds, y_valid)

# %%
# There are value differences in training data and validation data and we have to deal with it first because if not
